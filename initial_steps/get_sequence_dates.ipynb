# %%
import pandas as pd
import numpy as np

# %%
all_map_df = pd.read_csv('/Users/jc33/google_drive/thesis/analysis/files/initial_steps/mapping_files/periods1-2-3_all_data_barcodes_map.txt',
                 parse_dates = {'dateTime': ['DateOfCollection']}, sep='\t', index_col='#SampleID')

# %%
flag_map_df = all_map_df[all_map_df['City'] == 'flagstaff']

# %%
flag_map_df[flag_map_df['City'] == 'toronto']
# Out:
# Empty DataFrame
# Columns: [dateTime, BarcodeSequence, LinkerPrimerSequence, TimeOfCollection, WeekDay, Notes, Cooler, Description, City, PlateLocation, Material, OfficeNumber, Row, Event, OfficeNumberPlateLocation, CityOfficeNumber, CityOfficeNumberLocation, Period, DaysSinceEpoch, Season]
# Index: []

# %%
first_run = pd.read_csv('/Users/jc33/google_drive/thesis/analysis/files/initial_steps/mapping_files/first_run_maps/ids_to_sequence.txt', squeeze=True)
second_run = pd.read_csv('/Users/jc33/google_drive/thesis/analysis/files/initial_steps/mapping_files/second_run_maps/master_seq_ids.txt', squeeze=True)

# %%
print len(second_run)
print len(first_run)
both_runs = list(first_run.append(second_run))


flag_ids = [i for i in both_runs if i.startswith('F')]
flag_ids
# Out:
# 781
# 843
# ['F1C.3.Ce.001',
#  'F1C.3.Dr.001',
#  'F1C.2.Ca.001',
#  'F1C.2.Ce.001',
#  'F1C.2.Dr.001',
#  'F1F.3.Ca.001',
#  'F1F.3.Ce.001',
#  'F1F.3.Dr.001',
#  'F1F.2.Ca.001',
#  'F1F.2.Ce.001',
#  'F1F.2.Dr.001',
#  'F1W.3.Ca.001',
#  'F1W.3.Ce.001',
#  'F1W.3.Dr.001',
#  'F1W.2.Ca.001',
#  'F1W.2.Ce.001',
#  'F1W.2.Dr.001',
#  'F2C.2.Ca.001',
#  'F2C.2.Ce.001',
#  'F2C.2.Dr.001',
#  'F2C.3.Ca.001',
#  'F2C.3.Ce.001',
#  'F2C.3.Dr.001',
#  'F2F.2.Ca.001',
#  'F2F.2.Ce.001',
#  'F2F.2.Dr.001',
#  'F2F.3.Ca.001',
#  'F2F.3.Ce.001',
#  'F2F.3.Dr.001',
#  'F2W.2.Ca.001',
#  'F2W.2.Ce.001',
#  'F2W.2.Dr.001',
#  'F2W.3.Ca.001',
#  'F2W.3.Ce.001',
#  'F2W.3.Dr.001',
#  'F3C.2.Ca.001',
#  'F3C.2.Ce.001',
#  'F3C.2.Dr.001',
#  'F3C.3.Ca.001',
#  'F3C.3.Ce.001',
#  'F3C.3.Dr.001',
#  'F3F.2.Ca.001',
#  'F3F.2.Ce.001',
#  'F3C.2.Dr.001',
#  'F3F.3.Ca.001',
#  'F3F.3.Ce.001',
#  'F3F.3.Dr.001',
#  'F3W.2.Ca.001',
#  'F3W.2.Ce.001',
#  'F3W.2.Dr.001',
#  'F3W.3.Ca.001',
#  'F3W.3.Ce.001',
# ...

# %%
set(flag_map_df.loc[ids_to_fil].dateTime)
# Out:
# {'1/27/14',
#  '1/6/14',
#  '10/14/13',
#  '11/4/13',
#  '2/17/14',
#  '6/27/03',
#  '6/27/13',
#  '6/29/13',
#  '7/1/13',
#  '7/15/13',
#  '7/17/13',
#  '7/19/13',
#  '8/2/13',
#  '8/4/13',
#  '8/6/13',
#  '9/23/13'}
