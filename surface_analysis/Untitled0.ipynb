# %%
import pandas as pd
import numpy as np
from os.path import join
import skbio

# %%
home = '../'

# %%
mapping_file = join(home, 'master_period_1-2-3_map_5182014.txt')
map_df = pd.read_csv(mapping_file, sep='\t', index_col='#SampleID')

# %%
weighted_dm = join(home, 'row_2_3_comps/output/beta_diversity/weighted_unifrac_otu_table_mc2_w_tax_no_pynast_failures_mc800.txt')
dm_df = pd.read_csv(weighted_dm, sep='\t', index_col=0)

# %%
dm_df = dm_df.drop('blankswab5')
dm_df = dm_df.drop('blankswab5', axis=1)

# %%
#stack the series and filter out the duplicates 
dm_series = dm_df.stack()
seen =  set()
for id_pair in dm_series.index.tolist():
    if id_pair[::-1] in seen:
        continue
    seen.add(id_pair)

    
seen = list(seen)
seen.sort()
seen
dm_series = dm_series[seen]

# %%
stack_df = pd.DataFrame(dm_series)
stack_df.columns = ['dist']

# %% [markdown]
# I need to write a function that takes a mapping file a collapsed distance matrix and a list of mapping file column headers and adds the intersection of those to the collapsed distance matrix

# %%
def add_combined_cols(mapping_file, distance_matrix, headers):
    for header in headers:
        re_stack_df = stack_df.reset_index()
        level_1 = map_df[header][re_stack_df['level_1']]
        level_0 = map_df[header][re_stack_df['level_0']]
        new = [i if i == j else 'different' for i, j in zip(level_0, level_1)]
        stack_df[header] = new
    return stack_df

# %%
headers = ['City', 'Office', 'Surface', 'OfficeLocation', 'Season', 'Row', 
           'CityOffice', 'CityOfficeLocation', 'CityOfficeLocationSeason']
new_stack_df = add_combined_cols(map_df, stack_df, headers)

# %%
new_stack_df
# Out:
#                                  dist       City     Office    Surface  \
# 3C.3.Dr.020  3C.3.Dr.020     0.000000  different  different  different
#              F1C.2.Ca.021    0.481196  different  different  different
#              F1C.2.Ca.022    0.689048  different  different  different
#              F1C.2.Ce.021    0.369437  different  different  different
#              F1C.2.Ce.022    0.690473  different  different  different
#              F1C.2.Ce.040    0.770880  different  different  different
#              F1C.2.Ce.041    0.690770  different  different  different
#              F1C.2.Ce.050    0.785816  different  different  different
#              F1C.2.Ce.059    0.690415  different  different  different
#              F1C.2.Dr.011    0.292406  different  different  different
#              F1C.2.Dr.021    0.448117  different  different  different
#              F1C.2.Dr.022    0.681226  different  different  different
#              F1C.2.Dr.040    0.661752  different  different  different
#              F1C.2.Dr.050    0.699671  different  different  different
#              F1C.2.Dr.059    0.687804  different  different  different
#              F1C.3.Ca.010    0.617058  different  different  different
#              F1C.3.Ca.019    0.281672  different  different  different
#              F1C.3.Ca.020    0.372428  different  different  different
#              F1C.3.Ca.021    0.623909  different  different  different
#              F1C.3.Ca.022    0.688905  different  different  different
#              F1C.3.Ca.040    0.690185  different  different  different
#              F1C.3.Ca.041    0.711885  different  different  different
#              F1C.3.Ca.050    0.676136  different  different  different
#              F1C.3.Ca.059    0.658963  different  different  different
#              F1C.3.Ce.002    0.196688  different  different  different
#              F1C.3.Ce.003    0.221172  different  different  different
#              F1C.3.Ce.010    0.360098  different  different  different
#              F1C.3.Ce.011    0.201086  different  different  different
#              F1C.3.Ce.012    0.525205  different  different  different
#              F1C.3.Ce.019    0.385237  different  different  different
# ...                               ...        ...        ...        ...
# T3W.3.Dr.059 T2C.3.Dr.031    0.270165    toronto  different    drywall
#              T2C.3.Dr.041    0.377013    toronto  different    drywall
#              T2C.3.Dr.059    0.288201    toronto  different    drywall
#              T2F.2.Ca.040    0.305847    toronto  different  different
#              T2F.2.Ca.059    0.398702    toronto  different  different
#              T2F.3.Ce.050    0.381850    toronto  different  different
#              T2F.3.Dr.031.b  0.414551    toronto  different    drywall
#              T2F.3.Dr.040    0.356409    toronto  different    drywall
#              T2W.2.Ce.023    0.358686    toronto  different  different
#              T2W.2.Ce.050    0.271686    toronto  different  different
#              T2W.2.Dr.041    0.373506    toronto  different    drywall
#              T2W.2.Dr.059    0.530261    toronto  different    drywall
#              T2W.3.Ce.022    0.361282    toronto  different  different
#              T2W.3.Dr.031    0.394681    toronto  different    drywall
#              T2W.3.Dr.041    0.313299    toronto  different    drywall
#              T2W.3.Dr.050    0.250538    toronto  different    drywall
#              T2W.3.Dr.059    0.321882    toronto  different    drywall
#              T3C.2.Dr.040    0.265418    toronto          3    drywall
#              T3C.2.Dr.041    0.314308    toronto          3    drywall
#              T3C.3.Ce.031    0.319334    toronto          3  different
#              T3C.3.Dr.031    0.330090    toronto          3    drywall
#              T3C.3.Dr.050    0.217884    toronto          3    drywall
#              T3C.3.Dr.059    0.266764    toronto          3    drywall
#              T3W.2.Ce.040    0.341910    toronto          3  different
#              T3W.2.Dr.023    0.355574    toronto          3    drywall
#              T3W.2.Dr.040    0.381099    toronto          3    drywall
#              T3W.3.Ca.059    0.331233    toronto          3  different
#              T3W.3.Ce.041    0.306653    toronto          3  different
#              T3W.3.Dr.041    0.332374    toronto          3    drywall
#              T3W.3.Dr.059    0.000000    toronto          3    drywall
#
#                             OfficeLocation     Season        Row CityOffice  \
# 3C.3.Dr.020  3C.3.Dr.020         different  different  different  different
#              F1C.2.Ca.021        different  different  different  different
#              F1C.2.Ca.022        different  different  different  different
#              F1C.2.Ce.021        different  different  different  different
#              F1C.2.Ce.022        different  different  different  different
#              F1C.2.Ce.040        different  different  different  different
#              F1C.2.Ce.041        different  different  different  different
#              F1C.2.Ce.050        different  different  different  different
#              F1C.2.Ce.059        different  different  different  different
#              F1C.2.Dr.011        different  different  different  different
#              F1C.2.Dr.021        different  different  different  different
#              F1C.2.Dr.022        different  different  different  different
#              F1C.2.Dr.040        different  different  different  different
#              F1C.2.Dr.050        different  different  different  different
#              F1C.2.Dr.059        different  different  different  different
#              F1C.3.Ca.010        different  different  different  different
#              F1C.3.Ca.019        different  different  different  different
#              F1C.3.Ca.020        different  different  different  different
#              F1C.3.Ca.021        different  different  different  different
#              F1C.3.Ca.022        different  different  different  different
#              F1C.3.Ca.040        different  different  different  different
#              F1C.3.Ca.041        different  different  different  different
#              F1C.3.Ca.050        different  different  different  different
#              F1C.3.Ca.059        different  different  different  different
#              F1C.3.Ce.002        different  different  different  different
#              F1C.3.Ce.003        different  different  different  different
#              F1C.3.Ce.010        different  different  different  different
#              F1C.3.Ce.011        different  different  different  different
#              F1C.3.Ce.012        different  different  different  different
#              F1C.3.Ce.019        different  different  different  different
# ...                                    ...        ...        ...        ...
# T3W.3.Dr.059 T2C.3.Dr.031        different  different          3  different
#              T2C.3.Dr.041        different     Winter          3  different
#              T2C.3.Dr.059        different     Winter          3  different
#              T2F.2.Ca.040        different  different  different  different
#              T2F.2.Ca.059        different     Winter  different  different
#              T2F.3.Ce.050        different     Winter          3  different
#              T2F.3.Dr.031.b      different  different          3  different
#              T2F.3.Dr.040        different  different          3  different
#              T2W.2.Ce.023             wall  different  different  different
#              T2W.2.Ce.050             wall     Winter  different  different
#              T2W.2.Dr.041             wall     Winter  different  different
#              T2W.2.Dr.059             wall     Winter  different  different
#              T2W.3.Ce.022             wall  different          3  different
#              T2W.3.Dr.031             wall  different          3  different
#              T2W.3.Dr.041             wall     Winter          3  different
#              T2W.3.Dr.050             wall     Winter          3  different
#              T2W.3.Dr.059             wall     Winter          3  different
#              T3C.2.Dr.040        different  different  different  toronto_3
#              T3C.2.Dr.041        different     Winter  different  toronto_3
#              T3C.3.Ce.031        different  different          3  toronto_3
#              T3C.3.Dr.031        different  different          3  toronto_3
#              T3C.3.Dr.050        different     Winter          3  toronto_3
#              T3C.3.Dr.059        different     Winter          3  toronto_3
#              T3W.2.Ce.040             wall  different  different  toronto_3
#              T3W.2.Dr.023             wall  different  different  toronto_3
#              T3W.2.Dr.040             wall  different  different  toronto_3
#              T3W.3.Ca.059             wall     Winter          3  toronto_3
#              T3W.3.Ce.041             wall     Winter          3  toronto_3
#              T3W.3.Dr.041             wall     Winter          3  toronto_3
#              T3W.3.Dr.059             wall     Winter          3  toronto_3
#
#                             CityOfficeLocation CityOfficeLocationSeason
# 3C.3.Dr.020  3C.3.Dr.020             different                different
#              F1C.2.Ca.021            different                different
#              F1C.2.Ca.022            different                different
#              F1C.2.Ce.021            different                different
#              F1C.2.Ce.022            different                different
#              F1C.2.Ce.040            different                different
#              F1C.2.Ce.041            different                different
#              F1C.2.Ce.050            different                different
#              F1C.2.Ce.059            different                different
#              F1C.2.Dr.011            different                different
#              F1C.2.Dr.021            different                different
#              F1C.2.Dr.022            different                different
#              F1C.2.Dr.040            different                different
#              F1C.2.Dr.050            different                different
#              F1C.2.Dr.059            different                different
#              F1C.3.Ca.010            different                different
#              F1C.3.Ca.019            different                different
#              F1C.3.Ca.020            different                different
#              F1C.3.Ca.021            different                different
#              F1C.3.Ca.022            different                different
#              F1C.3.Ca.040            different                different
#              F1C.3.Ca.041            different                different
#              F1C.3.Ca.050            different                different
#              F1C.3.Ca.059            different                different
#              F1C.3.Ce.002            different                different
#              F1C.3.Ce.003            different                different
#              F1C.3.Ce.010            different                different
#              F1C.3.Ce.011            different                different
#              F1C.3.Ce.012            different                different
#              F1C.3.Ce.019            different                different
# ...                                        ...                      ...
# T3W.3.Dr.059 T2C.3.Dr.031            different                different
#              T2C.3.Dr.041            different                different
#              T2C.3.Dr.059            different                different
#              T2F.2.Ca.040            different                different
#              T2F.2.Ca.059            different                different
#              T2F.3.Ce.050            different                different
#              T2F.3.Dr.031.b          different                different
#              T2F.3.Dr.040            different                different
#              T2W.2.Ce.023            different                different
#              T2W.2.Ce.050            different                different
#              T2W.2.Dr.041            different                different
#              T2W.2.Dr.059            different                different
#              T2W.3.Ce.022            different                different
#              T2W.3.Dr.031            different                different
#              T2W.3.Dr.041            different                different
#              T2W.3.Dr.050            different                different
#              T2W.3.Dr.059            different                different
#              T3C.2.Dr.040            different                different
#              T3C.2.Dr.041            different                different
#              T3C.3.Ce.031            different                different
#              T3C.3.Dr.031            different                different
#              T3C.3.Dr.050            different                different
#              T3C.3.Dr.059            different                different
#              T3W.2.Ce.040       toronto_3_wall                different
#              T3W.2.Dr.023       toronto_3_wall                different
#              T3W.2.Dr.040       toronto_3_wall                different
#              T3W.3.Ca.059       toronto_3_wall    toronto_3_wall_Winter
#              T3W.3.Ce.041       toronto_3_wall    toronto_3_wall_Winter
#              T3W.3.Dr.041       toronto_3_wall    toronto_3_wall_Winter
#              T3W.3.Dr.059       toronto_3_wall    toronto_3_wall_Winter
#
# [796953 rows x 10 columns]
