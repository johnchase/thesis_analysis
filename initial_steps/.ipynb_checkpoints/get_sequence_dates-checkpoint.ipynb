# %%
import pandas as pd
import numpy as np

# %%
all_map_df = pd.read_csv('/Users/jc33/google_drive/thesis/analysis/files/initial_steps/mapping_files/periods1-2-3_all_data_barcodes_map.txt',
                 parse_dates = {'dateTime': ['DateOfCollection']}, sep='\t', index_col='#SampleID')

# %%
flag_map_df = all_map_df[all_map_df['City'] == 'flagstaff']

# %%
flag_map_df[flag_map_df['City'] == 'toronto']
flag_map_df.loc[['T2W.2.Dr.059', 'T3C.2.Dr.059']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-37683181ff24> in <module>()
#       1 flag_map_df[flag_map_df['City'] == 'toronto']
# ----> 2 flag_map_df.loc[['T2W.2.Dr.059', 'T3C.2.Dr.059']]
#
# /Users/jc33/.virtualenvs/qiime-dev-old/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1192             return self._getitem_tuple(key)
#    1193         else:
# -> 1194             return self._getitem_axis(key, axis=0)
#    1195
#    1196     def _getitem_axis(self, key, axis=0):
#
# /Users/jc33/.virtualenvs/qiime-dev-old/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1325                     raise ValueError('Cannot index with multidimensional key')
#    1326
# -> 1327                 return self._getitem_iterable(key, axis=axis)
#    1328
#    1329             # nested tuple slicing
#
# /Users/jc33/.virtualenvs/qiime-dev-old/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_iterable(self, key, axis)
#     922     def _getitem_iterable(self, key, axis=0):
#     923         if self._should_validate_iterable(axis):
# --> 924             self._has_valid_type(key, axis)
#     925
#     926         labels = self.obj._get_axis(axis)
#
# /Users/jc33/.virtualenvs/qiime-dev-old/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1273
#    1274                 raise KeyError("None of [%s] are in the [%s]" %
# -> 1275                                (key, self.obj._get_axis_name(axis)))
#    1276
#    1277             return True
#
# KeyError: "None of [['T2W.2.Dr.059', 'T3C.2.Dr.059']] are in the [index]"

# %%
first_run = pd.read_csv('/Users/jc33/google_drive/thesis/analysis/files/initial_steps/mapping_files/first_run_maps/ids_to_sequence.txt', squeeze=True)
second_run = pd.read_csv('/Users/jc33/google_drive/thesis/analysis/files/initial_steps/mapping_files/second_run_maps/master_seq_ids.txt', squeeze=True)

# %%
print len(second_run)
print len(first_run)

both_runs = list(first_run.append(second_run))
type(both_runs)
# Out:
# 781
# 843
# list

# %%
flag_map_df.loc[both_runs]
# Out:
#              dateTime BarcodeSequence    LinkerPrimerSequence  \
# F1C.3.Ce.001  6/27/13    ATGTGCTGCTCG  CCGGACTACHVGGGTWTCTAAT
# F1C.3.Dr.001  6/27/13    GTTCCGGATTAG  CCGGACTACHVGGGTWTCTAAT
# F1C.2.Ca.001  6/27/13    AGCCTGGTACCT  CCGGACTACHVGGGTWTCTAAT
# F1C.2.Ce.001  6/27/13    TATTCAGCGGAC  CCGGACTACHVGGGTWTCTAAT
# F1C.2.Dr.001  6/27/13    GAAGCTTGAATC  CCGGACTACHVGGGTWTCTAAT
# F1F.3.Ca.001  6/27/13    ACTAGGATCAGT  CCGGACTACHVGGGTWTCTAAT
# F1F.3.Ce.001  6/27/13    AATCCTCGGAGT  CCGGACTACHVGGGTWTCTAAT
# F1F.3.Dr.001  6/27/13    GACCCTAGACCT  CCGGACTACHVGGGTWTCTAAT
# F1F.2.Ca.001  6/27/13    CAGAAGGTGTGG  CCGGACTACHVGGGTWTCTAAT
# F1F.2.Ce.001  6/27/13    ACCGATTAGGTA  CCGGACTACHVGGGTWTCTAAT
# F1F.2.Dr.001  6/27/13    GCTCCTTAGAAG  CCGGACTACHVGGGTWTCTAAT
# F1W.3.Ca.001  6/27/13    TACGTACGAAAC  CCGGACTACHVGGGTWTCTAAT
# F1W.3.Ce.001  6/27/13    CTGGACGCATTA  CCGGACTACHVGGGTWTCTAAT
# F1W.3.Dr.001  6/27/13    TCTCAGCGCGTA  CCGGACTACHVGGGTWTCTAAT
# F1W.2.Ca.001  6/27/13    TGGCGTCATTCG  CCGGACTACHVGGGTWTCTAAT
# F1W.2.Ce.001  6/27/13    ATCACATTCTCC  CCGGACTACHVGGGTWTCTAAT
# F1W.2.Dr.001  6/27/13    TCCCATTCCCAT  CCGGACTACHVGGGTWTCTAAT
# F2C.2.Ca.001  6/27/03    CAGACACTTCCG  CCGGACTACHVGGGTWTCTAAT
# F2C.2.Ce.001  6/27/03    GCACTGGCATAT  CCGGACTACHVGGGTWTCTAAT
# F2C.2.Dr.001  6/27/03    ACCCACCACTAG  CCGGACTACHVGGGTWTCTAAT
# F2C.3.Ca.001  6/27/03    TCACCATCCGAG  CCGGACTACHVGGGTWTCTAAT
# F2C.3.Ce.001  6/27/03    GGTTACGGTTAC  CCGGACTACHVGGGTWTCTAAT
# F2C.3.Dr.001  6/27/03    TCCTCTTTGGTC  CCGGACTACHVGGGTWTCTAAT
# F2F.2.Ca.001  6/27/03    TCCGAGTCACCA  CCGGACTACHVGGGTWTCTAAT
# F2F.2.Ce.001  6/27/03    GTTGATACGATG  CCGGACTACHVGGGTWTCTAAT
# F2F.2.Dr.001  6/27/03    TGAAAGCGGCGA  CCGGACTACHVGGGTWTCTAAT
# F2F.3.Ca.001  6/27/03    ACATCAGGTCAC  CCGGACTACHVGGGTWTCTAAT
# F2F.3.Ce.001  6/27/03    GTGTAGGTGCTT  CCGGACTACHVGGGTWTCTAAT
# F2F.3.Dr.001  6/27/03    GGCATTAGTTGA  CCGGACTACHVGGGTWTCTAAT
# F2W.2.Ca.001  6/27/03    ACACGACTATAG  CCGGACTACHVGGGTWTCTAAT
# ...               ...             ...                     ...
# T3W.3.Ca.059      NaN             NaN                     NaN
# T3W.3.Ce.059      NaN             NaN                     NaN
# T3W.3.Dr.059      NaN             NaN                     NaN
# T1C.2.Ca.059      NaN             NaN                     NaN
# T1C.2.Ce.059      NaN             NaN                     NaN
# T1C.2.Dr.059      NaN             NaN                     NaN
# T1F.2.Ca.059      NaN             NaN                     NaN
# T1F.2.Ce.059      NaN             NaN                     NaN
# T1F.2.Dr.059      NaN             NaN                     NaN
# T1W.2.Ca.059      NaN             NaN                     NaN
# T1W.2.Ce.059      NaN             NaN                     NaN
# T1W.2.Dr.059      NaN             NaN                     NaN
# T2C.2.Ca.059      NaN             NaN                     NaN
# T2C.2.Ce.059      NaN             NaN                     NaN
# T2C.2.Dr.059      NaN             NaN                     NaN
# T2F.2.Ca.059      NaN             NaN                     NaN
# T2F.2.Ce.059      NaN             NaN                     NaN
# T2F.2.Dr.059      NaN             NaN                     NaN
# T2W.2.Ca.059      NaN             NaN                     NaN
# T2W.2.Ce.059      NaN             NaN                     NaN
# T2W.2.Dr.059      NaN             NaN                     NaN
# T3C.2.Ca.059      NaN             NaN                     NaN
# T3C.2.Ce.059      NaN             NaN                     NaN
# T3C.2.Dr.059      NaN             NaN                     NaN
# T3F.2.Ca.059      NaN             NaN                     NaN
# T3F.2.Ce.059      NaN             NaN                     NaN
# T3F.2.Dr.059      NaN             NaN                     NaN
# T3W.2.Ca.059      NaN             NaN                     NaN
# T3W.2.Ce.059      NaN             NaN                     NaN
# T3W.2.Dr.059      NaN             NaN                     NaN
#
#              TimeOfCollection    WeekDay    Notes   Cooler   Description  \
# F1C.3.Ce.001          7:30:00   Thursday  no_data  no_data  F1C.3.Ce.001
# F1C.3.Dr.001          7:30:00   Thursday  no_data  no_data  F1C.3.Dr.001
# F1C.2.Ca.001          7:30:00   Thursday  no_data  no_data  F1C.2.Ca.001
# F1C.2.Ce.001          7:30:00   Thursday  no_data  no_data  F1C.2.Ce.001
# F1C.2.Dr.001          7:30:00   Thursday  no_data  no_data  F1C.2.Dr.001
# F1F.3.Ca.001          9:20:00   Thursday  no_data  no_data  F1F.3.Ca.001
# F1F.3.Ce.001          9:20:00   Thursday  no_data  no_data  F1F.3.Ce.001
# F1F.3.Dr.001          9:20:00   Thursday  no_data  no_data  F1F.3.Dr.001
# F1F.2.Ca.001          9:20:00   Thursday  no_data  no_data  F1F.2.Ca.001
# F1F.2.Ce.001          9:20:00   Thursday  no_data  no_data  F1F.2.Ce.001
# F1F.2.Dr.001          9:20:00   Thursday  no_data  no_data  F1F.2.Dr.001
# F1W.3.Ca.001          9:20:00   Thursday  no_data  no_data  F1W.3.Ca.001
# F1W.3.Ce.001          8:30:00   Thursday  no_data  no_data  F1W.3.Ce.001
# F1W.3.Dr.001          8:30:00   Thursday  no_data  no_data  F1W.3.Dr.001
# F1W.2.Ca.001          8:30:00   Thursday  no_data  no_data  F1W.2.Ca.001
# F1W.2.Ce.001          8:30:00   Thursday  no_data  no_data  F1W.2.Ce.001
# F1W.2.Dr.001          8:30:00   Thursday  no_data  no_data  F1W.2.Dr.001
# F2C.2.Ca.001         13:15:00  Wednesday  no_data  no_data  F2C.2.Ca.001
# F2C.2.Ce.001         13:15:00  Wednesday  no_data  no_data  F2C.2.Ce.001
# F2C.2.Dr.001         13:15:00  Wednesday  no_data  no_data  F2C.2.Dr.001
# F2C.3.Ca.001         13:15:00  Wednesday  no_data  no_data  F2C.3.Ca.001
# F2C.3.Ce.001         13:15:00  Wednesday  no_data  no_data  F2C.3.Ce.001
# F2C.3.Dr.001         13:15:00  Wednesday  no_data  no_data  F2C.3.Dr.001
# F2F.2.Ca.001         12:35:00  Wednesday  no_data  no_data  F2F.2.Ca.001
# F2F.2.Ce.001         12:35:00  Wednesday  no_data  no_data  F2F.2.Ce.001
# F2F.2.Dr.001         12:35:00  Wednesday  no_data  no_data  F2F.2.Dr.001
# F2F.3.Ca.001         12:35:00  Wednesday  no_data  no_data  F2F.3.Ca.001
# F2F.3.Ce.001         12:35:00  Wednesday  no_data  no_data  F2F.3.Ce.001
# F2F.3.Dr.001         12:35:00  Wednesday  no_data  no_data  F2F.3.Dr.001
# F2W.2.Ca.001         13:20:00  Wednesday  no_data  no_data  F2W.2.Ca.001
# ...                       ...        ...      ...      ...           ...
# T3W.3.Ca.059              NaN        NaN      NaN      NaN           NaN
# T3W.3.Ce.059              NaN        NaN      NaN      NaN           NaN
# T3W.3.Dr.059              NaN        NaN      NaN      NaN           NaN
# T1C.2.Ca.059              NaN        NaN      NaN      NaN           NaN
# T1C.2.Ce.059              NaN        NaN      NaN      NaN           NaN
# T1C.2.Dr.059              NaN        NaN      NaN      NaN           NaN
# T1F.2.Ca.059              NaN        NaN      NaN      NaN           NaN
# T1F.2.Ce.059              NaN        NaN      NaN      NaN           NaN
# T1F.2.Dr.059              NaN        NaN      NaN      NaN           NaN
# T1W.2.Ca.059              NaN        NaN      NaN      NaN           NaN
# T1W.2.Ce.059              NaN        NaN      NaN      NaN           NaN
# T1W.2.Dr.059              NaN        NaN      NaN      NaN           NaN
# T2C.2.Ca.059              NaN        NaN      NaN      NaN           NaN
# T2C.2.Ce.059              NaN        NaN      NaN      NaN           NaN
# T2C.2.Dr.059              NaN        NaN      NaN      NaN           NaN
# T2F.2.Ca.059              NaN        NaN      NaN      NaN           NaN
# T2F.2.Ce.059              NaN        NaN      NaN      NaN           NaN
# T2F.2.Dr.059              NaN        NaN      NaN      NaN           NaN
# T2W.2.Ca.059              NaN        NaN      NaN      NaN           NaN
# T2W.2.Ce.059              NaN        NaN      NaN      NaN           NaN
# T2W.2.Dr.059              NaN        NaN      NaN      NaN           NaN
# T3C.2.Ca.059              NaN        NaN      NaN      NaN           NaN
# T3C.2.Ce.059              NaN        NaN      NaN      NaN           NaN
# T3C.2.Dr.059              NaN        NaN      NaN      NaN           NaN
# T3F.2.Ca.059              NaN        NaN      NaN      NaN           NaN
# T3F.2.Ce.059              NaN        NaN      NaN      NaN           NaN
# T3F.2.Dr.059              NaN        NaN      NaN      NaN           NaN
# T3W.2.Ca.059              NaN        NaN      NaN      NaN           NaN
# T3W.2.Ce.059              NaN        NaN      NaN      NaN           NaN
# T3W.2.Dr.059              NaN        NaN      NaN      NaN           NaN
#
#                    City PlateLocation      Material OfficeNumber  Row  Event  \
# F1C.3.Ce.001  flagstaff       ceiling  ceiling_tile            1    3      1
# F1C.3.Dr.001  flagstaff       ceiling       drywall            1    3      1
# F1C.2.Ca.001  flagstaff       ceiling        carpet            1    2      1
# F1C.2.Ce.001  flagstaff       ceiling  ceiling_tile            1    2      1
# F1C.2.Dr.001  flagstaff       ceiling       drywall            1    2      1
# F1F.3.Ca.001  flagstaff         floor        carpet            1    3      1
# F1F.3.Ce.001  flagstaff         floor  ceiling_tile            1    3      1
# F1F.3.Dr.001  flagstaff         floor       drywall            1    3      1
# F1F.2.Ca.001  flagstaff         floor        carpet            1    2      1
# F1F.2.Ce.001  flagstaff         floor  ceiling_tile            1    2      1
# F1F.2.Dr.001  flagstaff         floor       drywall            1    2      1
# F1W.3.Ca.001  flagstaff          wall        carpet            1    3      1
# F1W.3.Ce.001  flagstaff          wall  ceiling_tile            1    3      1
# F1W.3.Dr.001  flagstaff          wall       drywall            1    3      1
# F1W.2.Ca.001  flagstaff          wall        carpet            1    2      1
# F1W.2.Ce.001  flagstaff          wall  ceiling_tile            1    2      1
# F1W.2.Dr.001  flagstaff          wall       drywall            1    2      1
# F2C.2.Ca.001  flagstaff       ceiling        carpet            2    2      1
# F2C.2.Ce.001  flagstaff       ceiling  ceiling_tile            2    2      1
# F2C.2.Dr.001  flagstaff       ceiling       drywall            2    2      1
# F2C.3.Ca.001  flagstaff       ceiling        carpet            2    3      1
# F2C.3.Ce.001  flagstaff       ceiling  ceiling_tile            2    3      1
# F2C.3.Dr.001  flagstaff       ceiling       drywall            2    3      1
# F2F.2.Ca.001  flagstaff         floor        carpet            2    2      1
# F2F.2.Ce.001  flagstaff         floor  ceiling_tile            2    2      1
# F2F.2.Dr.001  flagstaff         floor       drywall            2    2      1
# F2F.3.Ca.001  flagstaff         floor        carpet            2    3      1
# F2F.3.Ce.001  flagstaff         floor  ceiling_tile            2    3      1
# F2F.3.Dr.001  flagstaff         floor       drywall            2    3      1
# F2W.2.Ca.001  flagstaff          wall        carpet            2    2      1
# ...                 ...           ...           ...          ...  ...    ...
# T3W.3.Ca.059        NaN           NaN           NaN          NaN  NaN    NaN
# T3W.3.Ce.059        NaN           NaN           NaN          NaN  NaN    NaN
# T3W.3.Dr.059        NaN           NaN           NaN          NaN  NaN    NaN
# T1C.2.Ca.059        NaN           NaN           NaN          NaN  NaN    NaN
# T1C.2.Ce.059        NaN           NaN           NaN          NaN  NaN    NaN
# T1C.2.Dr.059        NaN           NaN           NaN          NaN  NaN    NaN
# T1F.2.Ca.059        NaN           NaN           NaN          NaN  NaN    NaN
# T1F.2.Ce.059        NaN           NaN           NaN          NaN  NaN    NaN
# T1F.2.Dr.059        NaN           NaN           NaN          NaN  NaN    NaN
# T1W.2.Ca.059        NaN           NaN           NaN          NaN  NaN    NaN
# T1W.2.Ce.059        NaN           NaN           NaN          NaN  NaN    NaN
# T1W.2.Dr.059        NaN           NaN           NaN          NaN  NaN    NaN
# T2C.2.Ca.059        NaN           NaN           NaN          NaN  NaN    NaN
# T2C.2.Ce.059        NaN           NaN           NaN          NaN  NaN    NaN
# T2C.2.Dr.059        NaN           NaN           NaN          NaN  NaN    NaN
# T2F.2.Ca.059        NaN           NaN           NaN          NaN  NaN    NaN
# T2F.2.Ce.059        NaN           NaN           NaN          NaN  NaN    NaN
# T2F.2.Dr.059        NaN           NaN           NaN          NaN  NaN    NaN
# T2W.2.Ca.059        NaN           NaN           NaN          NaN  NaN    NaN
# T2W.2.Ce.059        NaN           NaN           NaN          NaN  NaN    NaN
# T2W.2.Dr.059        NaN           NaN           NaN          NaN  NaN    NaN
# T3C.2.Ca.059        NaN           NaN           NaN          NaN  NaN    NaN
# T3C.2.Ce.059        NaN           NaN           NaN          NaN  NaN    NaN
# T3C.2.Dr.059        NaN           NaN           NaN          NaN  NaN    NaN
# T3F.2.Ca.059        NaN           NaN           NaN          NaN  NaN    NaN
# T3F.2.Ce.059        NaN           NaN           NaN          NaN  NaN    NaN
# T3F.2.Dr.059        NaN           NaN           NaN          NaN  NaN    NaN
# T3W.2.Ca.059        NaN           NaN           NaN          NaN  NaN    NaN
# T3W.2.Ce.059        NaN           NaN           NaN          NaN  NaN    NaN
# T3W.2.Dr.059        NaN           NaN           NaN          NaN  NaN    NaN
#
#              OfficeNumberPlateLocation CityOfficeNumber  \
# F1C.3.Ce.001                 1_ceiling      flagstaff_1
# F1C.3.Dr.001                 1_ceiling      flagstaff_1
# F1C.2.Ca.001                 1_ceiling      flagstaff_1
# F1C.2.Ce.001                 1_ceiling      flagstaff_1
# F1C.2.Dr.001                 1_ceiling      flagstaff_1
# F1F.3.Ca.001                   1_floor      flagstaff_1
# F1F.3.Ce.001                   1_floor      flagstaff_1
# F1F.3.Dr.001                   1_floor      flagstaff_1
# F1F.2.Ca.001                   1_floor      flagstaff_1
# F1F.2.Ce.001                   1_floor      flagstaff_1
# F1F.2.Dr.001                   1_floor      flagstaff_1
# F1W.3.Ca.001                    1_wall      flagstaff_1
# F1W.3.Ce.001                    1_wall      flagstaff_1
# F1W.3.Dr.001                    1_wall      flagstaff_1
# F1W.2.Ca.001                    1_wall      flagstaff_1
# F1W.2.Ce.001                    1_wall      flagstaff_1
# F1W.2.Dr.001                    1_wall      flagstaff_1
# F2C.2.Ca.001                 2_ceiling      flagstaff_2
# F2C.2.Ce.001                 2_ceiling      flagstaff_2
# F2C.2.Dr.001                 2_ceiling      flagstaff_2
# F2C.3.Ca.001                 2_ceiling      flagstaff_2
# F2C.3.Ce.001                 2_ceiling      flagstaff_2
# F2C.3.Dr.001                 2_ceiling      flagstaff_2
# F2F.2.Ca.001                   2_floor      flagstaff_2
# F2F.2.Ce.001                   2_floor      flagstaff_2
# F2F.2.Dr.001                   2_floor      flagstaff_2
# F2F.3.Ca.001                   2_floor      flagstaff_2
# F2F.3.Ce.001                   2_floor      flagstaff_2
# F2F.3.Dr.001                   2_floor      flagstaff_2
# F2W.2.Ca.001                    2_wall      flagstaff_2
# ...                                ...              ...
# T3W.3.Ca.059                       NaN              NaN
# T3W.3.Ce.059                       NaN              NaN
# T3W.3.Dr.059                       NaN              NaN
# T1C.2.Ca.059                       NaN              NaN
# T1C.2.Ce.059                       NaN              NaN
# T1C.2.Dr.059                       NaN              NaN
# T1F.2.Ca.059                       NaN              NaN
# T1F.2.Ce.059                       NaN              NaN
# T1F.2.Dr.059                       NaN              NaN
# T1W.2.Ca.059                       NaN              NaN
# T1W.2.Ce.059                       NaN              NaN
# T1W.2.Dr.059                       NaN              NaN
# T2C.2.Ca.059                       NaN              NaN
# T2C.2.Ce.059                       NaN              NaN
# T2C.2.Dr.059                       NaN              NaN
# T2F.2.Ca.059                       NaN              NaN
# T2F.2.Ce.059                       NaN              NaN
# T2F.2.Dr.059                       NaN              NaN
# T2W.2.Ca.059                       NaN              NaN
# T2W.2.Ce.059                       NaN              NaN
# T2W.2.Dr.059                       NaN              NaN
# T3C.2.Ca.059                       NaN              NaN
# T3C.2.Ce.059                       NaN              NaN
# T3C.2.Dr.059                       NaN              NaN
# T3F.2.Ca.059                       NaN              NaN
# T3F.2.Ce.059                       NaN              NaN
# T3F.2.Dr.059                       NaN              NaN
# T3W.2.Ca.059                       NaN              NaN
# T3W.2.Ce.059                       NaN              NaN
# T3W.2.Dr.059                       NaN              NaN
#
#              CityOfficeNumberLocation Period DaysSinceEpoch  Season
# F1C.3.Ce.001      flagstaff_1_ceiling      1          15883  summer
# F1C.3.Dr.001      flagstaff_1_ceiling      1          15883  summer
# F1C.2.Ca.001      flagstaff_1_ceiling      1          15883  summer
# F1C.2.Ce.001      flagstaff_1_ceiling      1          15883  summer
# F1C.2.Dr.001      flagstaff_1_ceiling      1          15883  summer
# F1F.3.Ca.001        flagstaff_1_floor      1          15883  summer
# F1F.3.Ce.001        flagstaff_1_floor      1          15883  summer
# F1F.3.Dr.001        flagstaff_1_floor      1          15883  summer
# F1F.2.Ca.001        flagstaff_1_floor      1          15883  summer
# F1F.2.Ce.001        flagstaff_1_floor      1          15883  summer
# F1F.2.Dr.001        flagstaff_1_floor      1          15883  summer
# F1W.3.Ca.001         flagstaff_1_wall      1          15883  summer
# F1W.3.Ce.001         flagstaff_1_wall      1          15883  summer
# F1W.3.Dr.001         flagstaff_1_wall      1          15883  summer
# F1W.2.Ca.001         flagstaff_1_wall      1          15883  summer
# F1W.2.Ce.001         flagstaff_1_wall      1          15883  summer
# F1W.2.Dr.001         flagstaff_1_wall      1          15883  summer
# F2C.2.Ca.001      flagstaff_2_ceiling      3          48754  winter
# F2C.2.Ce.001      flagstaff_2_ceiling      3          48754  winter
# F2C.2.Dr.001      flagstaff_2_ceiling      3          48754  winter
# F2C.3.Ca.001      flagstaff_2_ceiling      3          48754  winter
# F2C.3.Ce.001      flagstaff_2_ceiling      3          48754  winter
# F2C.3.Dr.001      flagstaff_2_ceiling      3          48754  winter
# F2F.2.Ca.001        flagstaff_2_floor      3          48754  winter
# F2F.2.Ce.001        flagstaff_2_floor      3          15883  summer
# F2F.2.Dr.001        flagstaff_2_floor      3          48754  winter
# F2F.3.Ca.001        flagstaff_2_floor      3          48754  winter
# F2F.3.Ce.001        flagstaff_2_floor      3          48754  winter
# F2F.3.Dr.001        flagstaff_2_floor      3          48754  winter
# F2W.2.Ca.001         flagstaff_2_wall      3          15883  winter
# ...                               ...    ...            ...     ...
# T3W.3.Ca.059                      NaN    NaN            NaN     NaN
# T3W.3.Ce.059                      NaN    NaN            NaN     NaN
# T3W.3.Dr.059                      NaN    NaN            NaN     NaN
# T1C.2.Ca.059                      NaN    NaN            NaN     NaN
# T1C.2.Ce.059                      NaN    NaN            NaN     NaN
# T1C.2.Dr.059                      NaN    NaN            NaN     NaN
# T1F.2.Ca.059                      NaN    NaN            NaN     NaN
# T1F.2.Ce.059                      NaN    NaN            NaN     NaN
# T1F.2.Dr.059                      NaN    NaN            NaN     NaN
# T1W.2.Ca.059                      NaN    NaN            NaN     NaN
# T1W.2.Ce.059                      NaN    NaN            NaN     NaN
# T1W.2.Dr.059                      NaN    NaN            NaN     NaN
# T2C.2.Ca.059                      NaN    NaN            NaN     NaN
# T2C.2.Ce.059                      NaN    NaN            NaN     NaN
# T2C.2.Dr.059                      NaN    NaN            NaN     NaN
# T2F.2.Ca.059                      NaN    NaN            NaN     NaN
# T2F.2.Ce.059                      NaN    NaN            NaN     NaN
# T2F.2.Dr.059                      NaN    NaN            NaN     NaN
# T2W.2.Ca.059                      NaN    NaN            NaN     NaN
# T2W.2.Ce.059                      NaN    NaN            NaN     NaN
# T2W.2.Dr.059                      NaN    NaN            NaN     NaN
# T3C.2.Ca.059                      NaN    NaN            NaN     NaN
# T3C.2.Ce.059                      NaN    NaN            NaN     NaN
# T3C.2.Dr.059                      NaN    NaN            NaN     NaN
# T3F.2.Ca.059                      NaN    NaN            NaN     NaN
# T3F.2.Ce.059                      NaN    NaN            NaN     NaN
# T3F.2.Dr.059                      NaN    NaN            NaN     NaN
# T3W.2.Ca.059                      NaN    NaN            NaN     NaN
# T3W.2.Ce.059                      NaN    NaN            NaN     NaN
# T3W.2.Dr.059                      NaN    NaN            NaN     NaN
#
# [1624 rows x 20 columns]
