# %% [markdown]
# This notebook contains some experiments to collapse replicate samples for analysis with QIIME. Ideas for this are being discussed in [QIIME's #1678](https://github.com/biocore/qiime/issues/1678).
#
# This involves two steps:
#     1. collapsing sample metadata, and
#     2. collapsing samples in a BIOM table.
#
# I'm approaching this by first using the sample metadata (in a pandas DataFrame) to determine which sample ids belong to a replicate group, and then using those to collapse the BIOM table.

# %% [markdown]
# First we'll collapse samples in the mapping file with pandas.

# %%
import pandas as pd
import numpy as np

# %%
sample_md = pd.read_csv('/Users/jc33/google_drive/thesis/analysis/files/initial_steps/mapping_files/periods1-2-3_all_data_barcodes_map.txt', sep='\t')

# %%
sample_md['COLME'] = sample_md['#SampleID'].str[:3] + sample_md['#SampleID'].str[8:]

# %% [markdown]
# First we'll [group the sample ids](http://pandas.pydata.org/pandas-docs/stable/groupby.html#splitting-an-object-into-groups).

# %%
grouped = sample_md.groupby(['COLME'])

# %% [markdown]
# Next we'll [aggregate](http://pandas.pydata.org/pandas-docs/stable/groupby.html#aggregation). You can specify a function per metadata category that you want to aggregate. Here we want to retain the grouping of input sample ids, so I'm doing that by tuplizing the collection of sample ids in each group while aggregating.

# %%
collapsed_md = grouped.agg({'#SampleID':lambda x: tuple(x)})
collapsed_md[:4]

# %%
for e in collapsed_md.index:
    print e, set(collapsed_md['#SampleID'][e])

# %%
collapsed_md = collapsed_md.reset_index()
collapsed_md[:3]

# %%
sample_id_groups = collapsed_md[['#SampleID', 'COLME']]
sample_id_groups[:3]

# %%
set(sample_id_groups)

# %%
sid_to_group_id = {}
for group_id, sample_ids in sample_id_groups.iteritems():
    for sample_id in sample_ids:
        sid_to_group_id[sample_id] = group_id
print sid_to_group_id

# %%
# sid_to_group_id = {}
# for group_id, sample_ids in sample_id_groups.iteritems():
#     for sample_id in sample_ids:
#         sid_to_group_id[sample_id] = group_id
# print sid_to_group_id

# sample_id_groups = sample_id_groups.set_index('#SampleID')
sample_id_groups.to_dict()['COLME']

# %% [markdown]
# Now we're ready to collapse replicate groups in our BIOM file.

# %%
def group_by_sample_metadata(mapping_f, collapse_fields,
                             sample_id_field="#SampleID"):
    """Group sample identifiers by one or more metadata fields

    Parameters
    ----------
    mapping_f : file handle or filepath
        The sample metadata mapping file.
    collapse_fields : iterable
        The fields to combine when collapsing samples. For each sample in the
        mapping_f, the ordered values from these columns will be tuplized as
        used as the group identfier. Samples whose tuplized values in these
        fields are identical will be grouped.
    sample_id_field : str, optional
        The sample id field in the mapping_f.

    Returns
    -------
    dict
        Mapping of group id to set of input sample ids in that group.
    dict
        Mapping of input sample id to new group id.

    Raises
    ------
    KeyError
        If sample_id_field or any of the collapse fields are not column headers
        in mapping_f.

    """
    sample_md = pd.read_csv(mapping_f, sep='\t')
    grouped = sample_md.groupby(collapse_fields)
    collapsed_md = grouped.agg({sample_id_field:lambda x: tuple(x)})

    new_index_to_group = {}
    old_index_to_new_index = {}
    for i in collapsed_md.index:
        old_indices = collapsed_md[sample_id_field][i]

        # this is a little ugly, but we need to handle single and multi-index
        # values here, and we always want to result to be a tuple
        if isinstance(i, tuple):
            new_index = i
        else:
            new_index = (i, )

        new_index_to_group[new_index] = set(old_indices)
        for old_index in old_indices:
            old_index_to_new_index[old_index] = new_index

    return new_index_to_group, old_index_to_new_index

# %%
sample_md.columns.values
# Out:
# array(['#SampleID', 'BarcodeSequence', 'LinkerPrimerSequence',
#        'DateOfCollection', 'TimeOfCollection', 'WeekDay', 'Notes',
#        'Cooler', 'Description', 'City', 'PlateLocation', 'Material',
#        'OfficeNumber', 'Row', 'Event', 'OfficeNumberPlateLocation',
#        'CityOfficeNumber', 'CityOfficeNumberLocation', 'Period',
#        'DaysSinceEpoch', 'Season'], dtype=object)

# %%
map_fp = '/Users/jc33/google_drive/thesis/analysis/files/initial_steps/mapping_files/periods1-2-3_all_data_barcodes_map.txt'

# %%
new_index_to_group, old_index_to_new_index = group_by_sample_metadata(map_fp, ['City', 'PlateLocation', 'OfficeNumber', 'Row', 'Event'])

# %%
from biom import load_table

# %%
t = load_table('/Users/jc33/google_drive/thesis/analysis/files/row_2_3_comps/otu_table_mc800_w_tax_no_pynast_failures.biom')

# %%
print t

# %%
def partition_f(id_, md=None):
    return old_index_to_new_index[id_]

for i in t.ids():
    print i 
    try:
        partition_f(i)
    except:
        print i
# Out:
# F1F.3.Ca.020
# F2C.3.Ce.019
# F1F.3.Ce.050
# F2F.3.Ce.050
# F2C.3.Dr.050
# T2F.2.Dr.041
# S2F.2.Dr.042
# T1C.3.Ce.010
# T3F.3.Ce.003
# S3W.3.Ca.003
# S3C.3.Ca.023
# F2W.3.Ca.003
# S2C.3.Ce.023
# F3F.2.Ce.021
# T2F.3.Ca.031
# T3F.2.Ce.050
# T3F.3.Ca.059
# T2C.3.Dr.022
# T3W.2.Dr.023
# T3F.2.Dr.059
# F2F.2.Dr.050
# T2F.2.Ce.041
# S1F.3.Ce.042
# F1F.2.Ce.050
# F3F.2.Ca.050
# T1F.3.Ce.050
# T1F.3.Ca.050
# F3F.2.Ce.040
# T2F.2.Dr.059
# S1F.3.Ca.042
# T3F.3.Dr.022
# F2F.2.Ce.050
# F3F.2.Ce.059
# T2F.2.Dr.050
# F2W.3.Ce.041
# S2F.2.Ce.041
# F2F.2.Dr.059
# F2F.3.Ce.022
# S2F.2.Ce.042
# F3F.2.Ce.050
# T1F.3.Ce.040
# S1F.3.Dr.024
# F2F.2.Ce.059
# S1F.2.Dr.033
# F2F.2.Ce.040
# F1F.2.Dr.040
# T3F.3.Dr.041
# F2W.3.Ca.059
# F2C.3.Ce.050
# S3C.3.Dr.004
# F3W.2.Dr.050
# S3W.3.Ca.041
# F2W.3.Dr.002
# F3F.3.Dr.059
# F3F.3.Ce.031
# F3W.3.Ce.003
# F3W.3.Dr.002
# F3C.3.Ca.041
# F3F.2.Dr.059
# F3F.3.Ce.059
# F1F.2.Ca.022
# F2W.2.Dr.059
# T3F.3.Ca.021
# F3F.3.Ca.003
# F2F.3.Ca.021
# F2C.3.Dr.021
# S2C.3.Dr.042
# S2C.3.Ce.012
# F3C.2.Ce.050
# F2C.3.Dr.003
# T1W.3.Ce.020
# S1W.3.Ce.023
# S1F.2.Ca.042
# S1W.3.Ca.012
# F1F.3.Ca.059
# S2F.3.Dr.024
# S2W.2.Ce.042
# F1W.3.Ca.022
# F2F.2.Dr.041
# F2W.3.Dr.012
# F1F.2.Ce.022
# S3W.2.Ca.041
# F2F.3.Ce.019
# F2W.3.Ca.040
# T1W.3.Ce.022
# T2F.2.Ca.050
# T2F.2.Dr.023
# S1C.3.Ce.003
# T2F.3.Ca.041
# S1W.3.Dr.024
# F3W.3.Ce.059
# F3W.3.Ce.021
# T3F.3.Ca.010
# T3F.3.Dr.001
# T3C.3.Dr.021
# F1C.3.Ca.010
# F2C.2.Ce.011
# F1F.3.Ce.019
# F2F.2.Ce.011
# T3C.3.Dr.020
# T2W.3.Ce.020
# F1W.3.Ce.020
# S3W.3.Ca.004
# T1F.2.Dr.023
# F3C.3.Ce.050
# T1F.2.Dr.040
# S1W.3.Dr.004
# F3W.3.Ce.010
# S1W.3.Dr.001
# S1C.3.Ca.003
# F2W.2.Ca.021
# F3F.3.Ca.010
# T1F.3.Ce.021
# S3F.3.Ca.004
# F1F.2.Ce.021
# T3F.3.Ca.020
# F2F.3.Ca.020
# F1C.3.Ca.021
# S2W.3.Ca.005
# F2F.3.Ca.019
# F2W.3.Ce.011
# F2F.3.Ce.002
# F3W.3.Ce.011
# F3W.3.Ce.002
# F2W.2.Ce.011
# F2C.3.Ca.019
# S3C.2.Ca.060
# T3F.2.Ce.023
# F3F.3.Ce.041
# S1C.3.Dr.024
# S2F.3.Dr.042
# F3W.3.Ca.059
# T1F.2.Ce.041
# F1C.2.Dr.022
# T2W.3.Ce.059
# S3F.3.Ce.024
# F2W.2.Ca.022
# T1F.3.Dr.041
# T2F.3.Ce.022
# T1F.2.Ce.050
# F3F.3.Ca.059
# F3F.3.Dr.040
# F2C.3.Dr.040
# F1F.3.Ca.021
# F2C.3.Ce.020
# T3F.3.Ce.002
# F2W.3.Dr.059.a
# F1F.2.Dr.022
# F1W.2.Ce.022
# F1W.3.Ce.050
# F2C.3.Ce.041
# F1C.3.Dr.022
# F1C.2.Ce.040
# F3W.3.Ce.050
# F3F.3.Dr.031
# F1F.3.Ce.020
# F3C.2.Ce.011
# F1C.2.Ce.050
# T2W.2.Dr.040
# F1W.2.Ca.022
# T2W.3.Ca.001
# T1F.3.Ca.019
# T3C.3.Ce.002
# S3C.3.Ce.021
# T1W.3.Ca.002
# T1W.3.Ce.001
# S2C.3.Dr.004
# T2W.3.Dr.010
# T1F.3.Ce.019
# F3F.3.Ce.002
# S1C.3.Ce.004
# S2C.3.Ce.003
# S2F.3.Ca.021
# F3C.3.Ca.003
# F1F.3.Ce.010
# F3C.3.Ca.020
# F2F.3.Dr.003
# F2W.2.Ce.040
# F3F.3.Ca.031
# F1W.2.Ca.050
# F2W.3.Ce.059
# T3C.3.Ce.059
# S1W.2.Ca.060
# F1F.2.Ca.040
# F1W.2.Dr.040
# T3C.2.Ce.050
# F1C.3.Dr.059
# T3W.2.Ce.041
# T3F.3.Ce.059
# S3F.2.Dr.060
# T1C.2.Ce.041
# F3W.2.Dr.059
# S2C.2.Dr.041
# F1C.3.Dr.031
# S1W.3.Dr.033
# T2W.3.Dr.040
# F2C.2.Dr.041
# T2C.2.Ce.040
# S3F.3.Ce.051
# S3C.3.Ca.042
# T2C.3.Dr.050
# F2W.2.Ce.059
# S2C.3.Ce.051
# S3C.3.Dr.041
# T3W.3.Ce.031
# T2W.2.Dr.050
# S3W.2.Ce.060
# S1C.3.Ca.041
# T1W.3.Ce.050
# F2C.2.Ce.041
# T2C.2.Dr.040
# S3C.3.Dr.024
# S3F.3.Dr.024
# T2C.2.Ce.041
# F2W.3.Dr.041
# T3W.2.Ce.059
# F1F.2.Ca.041
# T3C.3.Dr.022
# F2F.2.Dr.011
# F3F.2.Dr.011
# F2F.3.Ce.010
# F3F.3.Dr.010
# S2W.2.Ce.041
# S2C.3.Ca.024
# S3F.3.Dr.051
# S3F.2.Ca.041
# S1F.2.Ca.041
# F3C.3.Dr.003
# T3W.3.Ce.002
# T3W.3.Ca.001
# F2W.3.Ce.020
# F3C.2.Dr.011
# F1C.2.Ca.021
# F3W.3.Ca.020
# S3C.3.Ca.003
# F2C.3.Ce.003
# F3F.3.Ce.020
# F1C.3.Dr.010
# F3W.3.Ca.050
# F1F.3.Ca.022
# F1W.3.Ca.041
# T2C.3.Dr.059
# F1W.2.Ca.040
# F1C.3.Ce.040
# T3W.3.Dr.059
# F1W.3.Dr.040
# F3C.3.Dr.050
# S1F.3.Dr.060
# S2C.3.Ce.041
# F3W.2.Dr.022
# S2F.3.Ca.041
# F3W.3.Ca.040
# S3C.2.Dr.060
# F1C.3.Ca.022
# F1W.3.Ce.031
# F1C.2.Ce.041
# S2W.3.Dr.051
# F1W.2.Dr.022
# S3C.3.Ce.060
# S3W.2.Dr.041
# F2C.3.Ce.031
# F1C.2.Ca.022
# S1W.2.Ce.042
# S2W.3.Dr.042
# F1F.3.Ce.022
# F1W.3.Dr.041
# F3W.2.Ce.041
# S3F.2.Dr.041
# S1C.3.Ca.024
# S2W.2.Ca.041
# T2C.2.Dr.050
# S2C.3.Ce.042
# T1W.3.Dr.022
# S2F.3.Ce.051
# T2W.3.Dr.041
# F3C.2.Dr.041
# T1C.2.Ce.059
# T1F.2.Dr.059
# S1W.3.Ce.042
# F1W.3.Ce.021
# S1C.3.Ce.060
# F1W.3.Dr.003
# T2F.3.Ca.020
# T3W.3.Ce.001
# S1C.3.Ce.021
# S3C.3.Dr.003
# F3F.3.Dr.011
# S3C.3.Ca.010
# T2C.3.Ca.002
# T3F.3.Ca.019
# F2F.3.Dr.019
# S1C.3.Ce.033
# S3W.3.Ce.004
# T2W.3.Ce.021
# F1C.3.Dr.021
# T2W.3.Ca.019
# S1C.3.Dr.012
# S2F.3.Dr.023
# F1F.3.Dr.021
# S3C.3.Ce.004
# S1W.3.Ce.004
# T3C.3.Dr.050
# T1C.3.Dr.059
# F1F.3.Dr.031
# T1W.2.Ce.040
# T2C.3.Dr.041
# T2F.2.Ce.059
# T3C.2.Dr.041
# F3W.2.Ce.040
# F2W.3.Dr.050
# T2W.3.Dr.003
# F3W.3.Ce.019
# S1W.3.Dr.005
# S3W.3.Ce.021
# T3F.3.Ca.002
# S1C.3.Ce.023
# T1F.3.Ce.010
# F1W.3.Dr.021
# T3C.3.Ca.019
# F1F.3.Ce.021
# F1W.3.Ce.002
# T2W.3.Ca.003
# S1C.3.Ce.012
# F2W.3.Ca.012
# S2W.3.Dr.012
# T2F.3.Ca.019
# S2C.3.Dr.005
# S1W.3.Ca.033
# T3W.3.Ce.041
# T1W.2.Dr.059
# F1W.2.Dr.050
# F1C.3.Ce.031
# T2W.2.Ce.023
# S1W.3.Ca.060
# F2C.3.Ca.059
# F3C.3.Ca.031
# T3W.2.Dr.050
# S2C.2.Dr.060
# T2W.3.Ce.031
# F1W.3.Dr.031
# F3C.3.Dr.022
# S1W.3.Ca.042
# S2C.3.Ce.024
# S2C.3.Dr.033
# T2C.2.Dr.059
# F2F.3.Dr.040
# F3C.3.Dr.040
# F2W.3.Ca.022
# T2W.2.Dr.041
# F3C.3.Dr.041
# S3C.3.Dr.033
# S2C.3.Ce.060
# T3W.2.Dr.059
# F1C.3.Ca.040
# S3W.2.Ca.042
# T1C.2.Dr.041
# F3C.3.Ce.031
# F2C.2.Dr.022
# T1W.3.Ce.040
# F1W.3.Ce.022
# T2F.3.Dr.031.b
# S3W.3.Ca.051
# T1C.3.Ca.059
# S3C.2.Ce.042
# F3W.3.Ca.031
# S1W.3.Dr.051
# S1W.3.Ce.024
# S1F.3.Ca.051
# S3W.3.Dr.042
# S1C.2.Ce.042
# S2W.3.Ce.033
# S1C.3.Ce.024
# S1C.3.Dr.041
# S2W.2.Dr.060
# T1C.2.Ce.040
# S1W.2.Ce.041
# S3W.3.Dr.024
# T3C.3.Ce.041
# T3W.3.Dr.041
# F1C.2.Dr.059
# S3W.3.Ca.024
# F1W.2.Dr.041
# T1C.2.Ce.023
# F3C.3.Ce.041
# F2W.3.Ca.031
# T2C.2.Ce.050
# S1F.3.Dr.033
# T3C.3.Dr.041
# T3W.2.Dr.040
# S3F.3.Dr.021
# S2C.3.Dr.012
# T3C.3.Dr.031
# S3C.3.Ce.003
# F2C.3.Ce.010
# T3W.3.Dr.001
# F3F.3.Ca.020
# S1F.3.Ca.023
# T1F.3.Dr.002
# S1C.3.Ca.005
# S3W.3.Dr.021
# F1C.3.Ce.010
# S2C.3.Dr.003
# F2W.3.Dr.003
# S3C.3.Ca.033
# F3C.3.Ca.019
# T1W.3.Dr.019
# S1F.3.Ca.004
# S2F.3.Ca.012
# S2F.3.Ca.004
# S1F.3.Ce.022
# S1W.2.Dr.041
# T2W.3.Dr.002
# F3F.2.Ce.011
# F1W.3.Ca.021
# F3F.3.Ce.010
# F3F.3.Dr.020
# F1C.3.Dr.020
# S2C.3.Ca.041
# T1W.3.Dr.002
# F1F.2.Dr.021
# S3C.3.Ca.004
# T3W.3.Dr.003
# F2F.3.Ce.020
# T2W.3.Ce.003
# S1F.3.Dr.004
# F2W.3.Dr.020
# S2C.2.Dr.003
# F3C.2.Ce.021
# F2W.3.Ce.019
# T3F.3.Ce.019
# S3F.3.Ca.022
# T3C.3.Ca.020
# T1F.3.Ca.003
# S3F.3.Dr.023
# S2W.3.Dr.010
# T2F.3.Dr.002
# S3C.3.Dr.023
# S2C.2.Ce.042
# S2W.3.Ce.024
# T2W.3.Dr.059
# S3F.3.Dr.041
# S3W.3.Ce.060
# F3C.3.Dr.011
# F2C.3.Ce.011
# S3C.3.Ce.023
# F2W.3.Ca.021
# F1W.3.Dr.020
# T2F.3.Dr.040
# S1C.3.Ca.022
# S2C.3.Ca.051
# S3C.3.Dr.022
# T2F.3.Ce.020
# S3W.3.Ce.010
# S2C.3.Ca.004
# S1C.3.Ca.004
# S2C.2.Ca.003
# S3W.3.Dr.010
# T2C.3.Ca.021
# S1C.3.Ca.002
# F3C.2.Ca.021
# T1C.3.Dr.019
# T1C.3.Dr.050
# T3C.3.Ca.059
# T2C.3.Dr.031
# S1C.3.Ce.041
# S3W.3.Ce.041
# S1W.3.Ce.033
# T3W.3.Ce.022
# T3C.3.Ce.031
# T1F.3.Dr.010
# T1F.3.Ce.003
# F3W.2.Ce.011
# F1W.3.Ca.031
# T2F.3.Ce.050
# T3C.3.Dr.002
# S2W.2.Dr.041
# T2C.3.Dr.020
# T1C.2.Dr.050
# T2W.3.Ce.001
# F2W.3.Ce.010
# T3W.3.Ce.010
# S3F.3.Ca.021
# F3W.3.Ce.020
# S1W.3.Ca.024
# S2F.3.Dr.004
# S1W.3.Ce.021
# T3F.3.Ce.020
# T1F.3.Dr.003
# T3W.3.Ca.020
# S2W.3.Ce.004
# S1F.3.Ca.005
# F1C.3.Ce.021
# S1C.3.Dr.033
# S1C.3.Dr.004
# S1C.2.Dr.060
# T2C.3.Ce.041
# T3C.2.Ce.041
# F1W.3.Dr.059
# S2W.3.Dr.060
# T1W.3.Ca.021
# S1F.3.Dr.003
# S1F.3.Dr.012
# S3F.3.Dr.005
# S1F.3.Ce.012
# S1F.3.Ce.041
# F2W.2.Dr.022
# T1F.3.Ce.022
# F1W.2.Ce.021
# T1F.3.Dr.059
# T1C.3.Ca.001
# T1W.3.Ce.021
# S2W.3.Ce.021
# F2C.3.Ca.021
# S1W.3.Ce.012
# S1W.3.Ce.002
# T2C.3.Ca.019
# S1W.3.Dr.011
# T1W.3.Dr.021
# S1W.3.Dr.002
# T3W.3.Ca.003
# S2C.3.Dr.021
# T2F.2.Ca.040
# F3C.3.Dr.031
# T1C.3.Ce.050
# T1W.3.Ce.041
# S2C.2.Ca.041
# T2W.2.Dr.059
# F1W.2.Ce.059
# T1C.3.Ce.022
# T2C.3.Ce.010
# S2W.3.Dr.004
# F2F.3.Ca.012
# F2C.3.Dr.012
# S2W.3.Ca.021
# S1F.3.Dr.002
# T2C.3.Dr.010
# F2C.3.Dr.031
# S1C.2.Dr.003
# F1W.3.Ce.003
# T2C.3.Ca.059
# T2W.3.Dr.031
# S2F.3.Ca.060
# F2C.3.Dr.010
# S1C.2.Ce.003
# T2F.3.Ce.010
# T2F.3.Ce.019
# S2C.3.Ca.012
# F1C.3.Ce.011
# F3W.3.Dr.003
# S3W.2.Ce.041
# S1F.3.Ca.002
# T1C.3.Dr.003
# T1W.3.Dr.003
# T2F.3.Dr.031.a
# S1W.2.Ca.041
# T2W.3.Ce.022
# S2W.3.Ca.060
# T3C.3.Dr.010
# S3W.3.Ca.021
# S3F.3.Ce.023
# T1F.3.Ce.002
# S3W.3.Dr.004
# S1W.3.Ce.022
# F2W.2.Dr.021
# T3C.3.Dr.059
# S3C.3.Ce.011
# T1C.3.Ca.019
# F1C.3.Dr.003
# F1F.3.Dr.019
# T1C.3.Dr.001
# T2C.3.Ce.031
# S1W.3.Dr.003
# T1W.2.Dr.041
# S2F.2.Dr.003
# S1C.3.Ca.023
# S2F.3.Ce.012
# T2W.3.Ce.010
# F1F.3.Dr.002
# S3C.3.Ca.022
# T2F.3.Ca.002
# F2W.2.Dr.041
# S2W.2.Ce.060
# T1W.3.Dr.041
# T1F.3.Ce.020
# S3F.3.Ce.003
# F1C.3.Ca.019
# T3W.3.Ce.021
# S1W.3.Ce.041
# F2W.3.Dr.010
# F2W.2.Dr.011
# F1W.3.Ce.019
# F1W.3.Ce.010
# T1W.3.Dr.040
# F2C.3.Ce.021
# T1C.3.Ca.010
# T1W.3.Dr.020
# S1F.3.Dr.021
# T3C.3.Ce.010
# F1W.3.Dr.010
# S3W.3.Ce.022
# T2C.3.Ce.020
# F1W.2.Ca.021
# S1F.3.Ce.002
# F2C.3.Dr.019
# T2C.3.Ce.002
# S2W.3.Ce.023
# S1F.2.Ce.003
# S1W.2.Ce.003
# T3C.3.Dr.003
# S2W.3.Ce.005
# T1C.3.Dr.002
# T2W.3.Ca.020
# S2F.3.Dr.022
# S2F.2.Ce.003
# S2C.3.Ca.010
# T2C.3.Dr.021
# S1F.3.Dr.023
# S3F.3.Ce.021
# S2F.3.Dr.021
# T3W.3.Ce.003
# S3W.3.Dr.003
# S2C.3.Ce.022
# S3W.3.Ce.003
# T1C.3.Ca.020
# F1W.3.Dr.002
# T1C.3.Ca.003
# S2W.3.Dr.021
# S1C.3.Dr.005
# T2F.3.Ca.010
# S1F.3.Ce.003
# T3F.3.Ca.003
# F1F.3.Ca.019
# T1C.3.Dr.020
# F1W.3.Ce.011
# T2C.3.Ce.021
# S2C.2.Ce.003
# T1W.3.Ce.010
# F2C.3.Dr.011
# S2C.3.Ca.023
# T2F.3.Ce.001
# S3C.3.Ce.022
# S1W.2.Dr.003
# blankswab5
# T3W.3.Dr.020
# T1C.3.Ce.003
# T2C.3.Ce.003
# F3C.3.Dr.021
# S2C.3.Dr.011
# T3C.3.Ce.021
# F1C.2.Dr.011
# T1W.3.Ca.020
# T2C.3.Ca.020
# T1W.3.Dr.059
# F1F.3.Ca.002
# T2C.3.Ce.050
# T2F.3.Ce.003
# F3C.2.Ce.040
# S2W.3.Dr.041
# T3C.2.Dr.040
# S1W.3.Ce.051
# T2W.2.Ce.050
# T2W.3.Dr.050
# T3C.3.Ce.020
# T1C.2.Dr.040
# S3C.3.Ca.024
# S2W.3.Ce.060
# S1C.3.Ce.002
# F2W.3.Dr.019
# S2W.2.Dr.003
# S1C.3.Ca.033
# S3W.3.Ca.042
# S3C.3.Ca.041
# T3W.3.Ca.059
# S2C.3.Dr.060
# T3W.3.Dr.040
# T3W.2.Ce.040
# F3W.3.Dr.022
# F2C.3.Ce.022
# S1C.3.Ca.060
# F3W.3.Dr.040
# T1C.3.Dr.031
# S3C.3.Ce.042
# S2W.3.Ca.024
# S1W.3.Ca.021
# S1F.2.Ce.042

# %%
small_t = t.filter(['F2F.2.Ce.059', 
'S1F.2.Dr.033',
'F2F.2.Ce.040',
'F1F.2.Dr.040',
'T3F.3.Dr.041',
'F2W.3.Ca.059',
'F2C.3.Ce.050',
'S3C.3.Dr.004',
'F3W.2.Dr.050',
'S3W.3.Ca.041',
'F2W.3.Dr.002'])
print small_t

# %%
small_t = t.collapse(partition_f, norm=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-8a1f69206a09> in <module>()
# ----> 1 small_t = t.collapse(partition_f, norm=False)
#
# /Users/jc33/.virtualenvs/qiime-dev/lib/python2.7/site-packages/biom/table.pyc in collapse(self, f, reduce_f, norm, min_group_size, include_collapsed_metadata, one_to_many, one_to_many_mode, one_to_many_md_key, strict, axis)
#    2077                     continue
#    2078
# -> 2079                 redux_data = table.reduce(reduce_f, self._invert_axis(axis))
#    2080                 if norm:
#    2081                     redux_data /= len(axis_ids)
#
# /Users/jc33/.virtualenvs/qiime-dev/lib/python2.7/site-packages/biom/table.pyc in reduce(self, f, axis)
#     658         # np.apply_along_axis might reduce type conversions here and improve
#     659         # speed. am opting for reduce right now as I think its more readable
# --> 660         return asarray([reduce(f, v) for v in self.iter_data(axis=axis)])
#     661
#     662     def sum(self, axis='whole'):
#
# /Users/jc33/.virtualenvs/qiime-dev/lib/python2.7/site-packages/biom/table.pyc in iter_data(self, dense, axis)
#    1330                     yield samp_v
#    1331         elif axis == "observation":
# -> 1332             for obs_v in self._iter_obs():
#    1333                 if dense:
#    1334                     yield self._to_dense(obs_v)
#
# /Users/jc33/.virtualenvs/qiime-dev/lib/python2.7/site-packages/biom/table.pyc in _iter_obs(self)
#    1140         """Return observation vectors of data matrix"""
#    1141         for r in range(self.shape[0]):
# -> 1142             yield self._get_row(r)
#    1143
#    1144     def get_table_density(self):
#
# /Users/jc33/.virtualenvs/qiime-dev/lib/python2.7/site-packages/biom/table.pyc in _get_row(self, row_idx)
#     585         """
#     586         self._data = self._data.tocsr()
# --> 587         return self._data.getrow(row_idx)
#     588
#     589     def _get_col(self, col_idx):
#
# /Users/jc33/.virtualenvs/qiime-dev/lib/python2.7/site-packages/scipy/sparse/csr.pyc in getrow(self, i)
#     303         CSR matrix (row vector).
#     304         """
# --> 305         return self._get_submatrix(i, slice(None))
#     306
#     307     def getcol(self, i):
#
# /Users/jc33/.virtualenvs/qiime-dev/lib/python2.7/site-packages/scipy/sparse/csr.pyc in _get_submatrix(self, row_slice, col_slice)
#     400         shape = (i1 - i0, j1 - j0)
#     401
# --> 402         return self.__class__((data,indices,indptr), shape=shape)
#     403
#     404
#
# /Users/jc33/.virtualenvs/qiime-dev/lib/python2.7/site-packages/scipy/sparse/compressed.pyc in __init__(self, arg1, shape, dtype, copy)
#      51                     # (data, indices, indptr) format
#      52                     (data, indices, indptr) = arg1
# ---> 53                     idx_dtype = get_index_dtype((indices, indptr), check_contents=True)
#      54                     self.indices = np.array(indices, copy=copy, dtype=idx_dtype)
#      55                     self.indptr = np.array(indptr, copy=copy, dtype=idx_dtype)
#
# /Users/jc33/.virtualenvs/qiime-dev/lib/python2.7/site-packages/scipy/sparse/sputils.pyc in get_index_dtype(arrays, maxval, check_contents)
#     163
#     164     for arr in arrays:
# --> 165         arr = np.asarray(arr)
#     166         if arr.dtype > np.int32:
#     167             if check_contents:
#
# /Users/jc33/.virtualenvs/qiime-dev/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     460
#     461     """
# --> 462     return array(a, dtype, copy=False, order=order)
#     463
#     464 def asanyarray(a, dtype=None, order=None):
#
# KeyboardInterrupt:

# %% [markdown]
# By default, observation counts are summed when collapsing samples. Some other common options are illustrated here.

# %% [markdown]
# ## Collapse to the first sample in each group

# %%
from biom.exception import UnknownAxisError
def collapse_to_first(t, axis):
    return np.asarray([e[0] for e in t.iter_data(axis=axis, dense=True)])

print t.collapse(partition_f, collapse_f=collapse_to_first, norm=False, axis='sample')

# %% [markdown]
# ## Collapse to the median value for each observation

# %%
def collapse_to_median(t, axis):
    return np.asarray([np.median(e) for e in t.iter_data(axis=axis, dense=True)])

print t.collapse(partition_f, collapse_f=collapse_to_median, norm=False, axis='sample')

# %% [markdown]
# ## Collapse to a randomly selected sample

# %%
from biom.exception import UnknownAxisError

def collapse_to_rand(t, axis):
    # this is a little clunky - waiting for an answer here
    # http://stackoverflow.com/q/26050412/3424666
    if axis == 'sample':
        length = t.shape[0]
    elif axis == 'observation':
        length = t.shape[1]
    else:
        raise UnknownAxisError(axis)
    n = np.random.randint(length)
    return np.asarray([e[n] for e in t.iter_data(axis=axis, dense=True)])

print t.collapse(partition_f, collapse_f=collapse_to_rand, norm=False, axis='sample')

# %%
print t.collapse(partition_f, collapse_f=collapse_to_rand, norm=False, axis='sample')

# %% [markdown]
# ## Sum counts

# %%
print t.collapse(partition_f, norm=False, axis='sample')

# %% [markdown]
# ## Average counts

# %%
print t.collapse(partition_f, norm=True, axis='sample')
